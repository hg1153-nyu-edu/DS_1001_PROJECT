# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
column_names = ('duration',
                'protocol_type',
                'service',
                'flag',
                'src_bytes',
                'dst_bytes',
                'land',
                'wrong_fragment',
                'urgent',
                'hot',
                'num_failed_logins',
                'logged_in',
                'num_compromised',
                'root_shell',
                'su_attempted',
                'num_root',
                'num_file_creations',
                'num_shells',
                'num_access_files',
                'num_outbound_cmds',
                'is_host_login',
                'is_guest_login',
                'count',
                'srv_count',
                'serror_rate',
                'srv_serror_rate',
                'rerror_rate',
                'srv_rerror_rate',
                'same_srv_rate',
                'diff_srv_rate',
                'srv_diff_host_rate',
                'dst_host_count',
                'dst_host_srv_count',
                'dst_host_same_srv_rate',
                'dst_host_diff_srv_rate',
                'dst_host_same_src_port_rate',
                'dst_host_srv_diff_host_rate',
                'dst_host_serror_rate',
                'dst_host_srv_serror_rate',
                'dst_host_rerror_rate',
                'dst_host_srv_rerror_rate',
                'attack_type',
                'difficulty_level')

data = pd.read_csv('../data/NSL-KDD/KDDTrain+_20Percent.txt', header=None, names=column_names)

data = data.drop(columns='difficulty_level')
data['Y'] = np.where(data['attack_type'] == 'normal', 0, 1)
data = data.drop(columns='attack_type')
data.shape
# Out:
# (25192, 42)

# %%
def attack_percentage(df):
    return df.sum() / df.count()

# %%
# delete variables with 0 variance
data = data.drop(columns=['num_outbound_cmds', 'is_host_login'])

# %%
# urgent & num_shells has max 1 but are not indicators
indicator_vars = ['land', 'logged_in', 'root_shell', 'su_attempted', 'is_hot_login', 'is_guest_login']

# %%
# create dummy variavbles
categorical_vars = data.select_dtypes(include=['object']).columns.tolist()
print(categorical_vars)
data = pd.get_dummies(data)
# Out:
# ['protocol_type', 'service', 'flag']

# %%
# urgent & num_shells has max 1 but are not indicators
# is_hot_login is an indicator but was dropped due to 0 variance
indicator_vars = ['land', 'logged_in', 'root_shell', 'su_attempted', 'is_guest_login']
indicator_vars = indicator_vars + data.columns.tolist()[38:]

# %% [markdown]
# #### Multicolinearity

# %%
import pandas as pd
import numpy as np

rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r' & 'BrBG' are other good diverging colormaps
# Out:
# <style  type="text/css" >
#     #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col1 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col2 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col3 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col4 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col7 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col8 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow0_col9 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col0 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col3 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col5 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col7 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col8 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow1_col9 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col0 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col4 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col6 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col7 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col0 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col1 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col4 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col6 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col7 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col8 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow3_col9 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col0 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col2 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col3 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col5 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col6 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow4_col9 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col1 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col2 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col4 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col6 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col7 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col8 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_2b520eb0_186a_11ea_a04c_8c85900d330drow5_col9 {
#             background-color:  #aec9fc;
#             color:  #000000;

# %%
figure = plt.figure(figsize=(8, 7))
plt.matshow(data.drop(columns=indicator_vars+['Y']).corr(), fignum=figure.number)
colorbar = plt.colorbar()
colorbar.ax.tick_params(labelsize=14)
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
corrmat = data.corr() 
f, ax = plt.subplots(figsize =(8, 7)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
figure = plt.figure(figsize=(8, 7))
corr = data.corr()
print(corr.shape)
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
# Out:
# (117, 117)

# %% [markdown]
# abs(correlation) > 0.9<br>
# num_compromised & num_root<br>
# serror_rate & srv_serror_rate & dst_host_serror_rate & dst_host_srv_serror_rate<br>
# rerror_rate & srv_rerror_rate & dst_host_rerror_rate & dst_host_srv_rerror_rate

# %%
data[['serror_rate', 'srv_serror_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate']].var()
# Out:
# serror_rate                 0.200088
# srv_serror_rate             0.200345
# dst_host_serror_rate        0.198307
# dst_host_srv_serror_rate    0.198983
# dtype: float64

# %%
data[['rerror_rate', 'srv_rerror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate']].var()
# Out:
# rerror_rate                 0.101599
# srv_rerror_rate             0.103900
# dst_host_rerror_rate        0.093556
# dst_host_srv_rerror_rate    0.100701
# dtype: float64

# %%
# drop
data = data.drop(columns=['num_compromised'])
data = data.drop(columns=['serror_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate'])
data = data.drop(columns=['rerror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate'])

# %%
# (data.drop(columns=indicator_vars+['Y']).corr() > 0.95).sum()
# (abs(data.drop(columns=indicator_vars+['Y']).corr()) > 0.9).sum()

# %% [markdown]
# # Feature Select

# %%
from sklearn.model_selection import train_test_split
X = data.drop(columns='Y').values
y = data['Y'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion='entropy')
tree.fit(X_train, y_train)
feature_importance = tree.feature_importances_

# %%
from operator import itemgetter

feature_names = data.drop(columns='Y').columns.tolist()
feature_importance = list(zip(feature_names, tree.feature_importances_))
feature_importance.sort(key=itemgetter(1))
feature_names, importance = zip(*feature_importance)

# plot
fig = plt.figure(figsize=(100,20))
y_pos = np.arange(len(feature_names))
plt.bar(y_pos, importance, align='center', alpha=0.6)
plt.xticks(y_pos, feature_names)
plt.xticks(fontsize=14)  
plt.yticks(fontsize=14)
plt.ylabel('Importance', fontsize=12)
plt.title('Feature Importance', fontsize=15)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-901c1061bf7c> in <module>
# ----> 1 X.columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
